# %% [markdown]
# ## Notebook para criar lessons no Banco de dados.
# #### Passo a Passo:
# 1. Join da tabela microareas com mesoareas
# 2. Itera em mesoareas
# 3. Para cada mesoárea, itera em 5 nivel_associado (1 a 5)
# 4. Para cada microarea, associa 2 unidades lessons com ordem_associado consecutivos

# %%
from sqlalchemy import (
create_engine,
Column,
Integer,
String,
ForeignKey,
DateTime,
func,
)
from sqlalchemy.orm import declarative_base, sessionmaker, relationship, joinedload
import logging
import random

DATABASE_URL = "postgresql://postgres:UHvDPeDKxUwaxpqlegotnlnDSlDjEUwn@yamabiko.proxy.rlwy.net:30592/railway"
DRY_RUN = True
LESSONS_PER_MICROAREA = 2
LEVELS = range(1, 6) # 1 a 5

Base = declarative_base()


class Mesoarea(Base):
    __tablename__ = "mesoarea"
    id = Column(Integer, primary_key=True)
    id_macroarea = Column(Integer, ForeignKey('macroarea.id'))
    nome = Column(String)
    friendly_name = Column(String)
    descricao = Column(String)



    microareas = relationship("Microarea", back_populates="mesoarea")


class Microarea(Base):
    __tablename__ = "microarea"
    id = Column(Integer, primary_key=True)
    id_mesoarea = Column(Integer, ForeignKey('mesoarea.id'))
    nome = Column(String)
    friendly_name = Column(String)
    videos_json = Column(String, nullable=True)


    mesoarea = relationship("Mesoarea", back_populates="microareas")
    lessons = relationship("Lesson", back_populates="microarea")


class Lesson(Base):
    __tablename__ = "lesson"
    id = Column(Integer, primary_key=True, autoincrement=True)
    id_microarea = Column(Integer, ForeignKey('microarea.id'))
    nivel_associado = Column(Integer)
    ordem_no_nivel = Column(Integer)
    type = Column(String)
    created_at = Column(DateTime, server_default=func.now())


    microarea = relationship("Microarea", back_populates="lessons")

engine = create_engine(DATABASE_URL)
Session = sessionmaker(bind=engine)

# %%
def get_mesoareas_with_microareas(session):
    """Retorna todas as mesoareas com suas microareas carregadas."""
    return session.query(Mesoarea).options(joinedload(Mesoarea.microareas)).all()

# %%
def create_lessons_for_mesoarea(session, mesoarea, lessons_per_microarea=2, levels=LEVELS):
    """
    Cria lessons do zero para cada microarea da mesoarea.
    - Para cada nivel em `levels`, cria `lessons_per_microarea` lessons por microarea.
    - No fim de cada nível, adiciona 2 lessons tipo 'simulado' com id_microarea=0.
    - Atribui ordem_no_nivel incremental dentro do nível (compartilhada pelas microareas + simulados).
    """
    microareas = mesoarea.microareas
    if not microareas:
        print(f"Mesoarea {mesoarea.id} não tem microareas. Pulando.")
        return []

    inserted = []

    for level in levels:
        ordem = 1  # reinicia a contagem de ordem para cada nível
        # lessons por microarea
        for micro in microareas:
            for _ in range(lessons_per_microarea):
                new_lesson = Lesson(
                    id_microarea=micro.id,
                    nivel_associado=level,
                    ordem_no_nivel=ordem,
                    type="licao",
                )
                inserted.append(new_lesson)
                print(f"Lesson -> micro:{micro.id} level:{level} ordem:{ordem} type:licao")
                ordem += 1

        # adiciona 2 simulados no final do nível
        for i in range(2):
            simulado = Lesson(
                id_microarea=0,
                nivel_associado=level,
                ordem_no_nivel=ordem,
                type="simulado",
            )
            inserted.append(simulado)
            print(f"Lesson -> micro:0 level:{level} ordem:{ordem} type:simulado")
            ordem += 1

    return inserted

# %%
session = Session()
try:
    mesoareas = get_mesoareas_with_microareas(session)
    print(f"Encontradas {len(mesoareas)} mesoareas")


    all_to_insert = []


    for meso in mesoareas:
        print(f"Processando mesoarea {meso.id} - {getattr(meso, 'nome', '')} (microareas: {len(meso.microareas)})")
        created = create_lessons_for_mesoarea(session, meso, lessons_per_microarea=LESSONS_PER_MICROAREA)
        print(f" -> Preparadas {len(created)} lessons para mesoarea {meso.id}")
        all_to_insert.extend(created)


    print(f"Total de lessons a inserir: {len(all_to_insert)}")

    # persiste em lote
    session.bulk_save_objects(all_to_insert)
    session.commit()
    print(f"Inseridas {len(all_to_insert)} rows na tabela lesson")


except Exception as e:
    print("Erro durante a execução")
    session.rollback()
    raise
finally:
    session.close()
# Out:
# WARNING:  database "railway" has a collation version mismatch
# DETAIL:  The database was created using collation version 2.36, but the operating system provides version 2.41.
# HINT:  Rebuild all objects in this database that use the default collation and run ALTER DATABASE railway REFRESH COLLATION VERSION, or build PostgreSQL with the right library version.
# Encontradas 20 mesoareas
# Processando mesoarea 2 - bioquimica (microareas: 5)
# Lesson -> micro:2 level:1 ordem:1 type:licao
# Lesson -> micro:2 level:1 ordem:2 type:licao
# Lesson -> micro:3 level:1 ordem:3 type:licao
# Lesson -> micro:3 level:1 ordem:4 type:licao
# Lesson -> micro:4 level:1 ordem:5 type:licao
# Lesson -> micro:4 level:1 ordem:6 type:licao
# Lesson -> micro:5 level:1 ordem:7 type:licao
# Lesson -> micro:5 level:1 ordem:8 type:licao
# Lesson -> micro:6 level:1 ordem:9 type:licao
# Lesson -> micro:6 level:1 ordem:10 type:licao
# Lesson -> micro:0 level:1 ordem:11 type:simulado
# Lesson -> micro:0 level:1 ordem:12 type:simulado
# Lesson -> micro:2 level:2 ordem:1 type:licao
# Lesson -> micro:2 level:2 ordem:2 type:licao
# Lesson -> micro:3 level:2 ordem:3 type:licao
# Lesson -> micro:3 level:2 ordem:4 type:licao
# Lesson -> micro:4 level:2 ordem:5 type:licao
# Lesson -> micro:4 level:2 ordem:6 type:licao
# Lesson -> micro:5 level:2 ordem:7 type:licao
# Lesson -> micro:5 level:2 ordem:8 type:licao
# Lesson -> micro:6 level:2 ordem:9 type:licao
# Lesson -> micro:6 level:2 ordem:10 type:licao
# Lesson -> micro:0 level:2 ordem:11 type:simulado
# Lesson -> micro:0 level:2 ordem:12 type:simulado
# Lesson -> micro:2 level:3 ordem:1 type:licao
# Lesson -> micro:2 level:3 ordem:2 type:licao
# Lesson -> micro:3 level:3 ordem:3 type:licao
# Lesson -> micro:3 level:3 ordem:4 type:licao
# Lesson -> micro:4 level:3 ordem:5 type:licao
# Lesson -> micro:4 level:3 ordem:6 type:licao
# Lesson -> micro:5 level:3 ordem:7 type:licao
# Lesson -> micro:5 level:3 ordem:8 type:licao
# Lesson -> micro:6 level:3 ordem:9 type:licao
# Lesson -> micro:6 level:3 ordem:10 type:licao
# Lesson -> micro:0 level:3 ordem:11 type:simulado
# Lesson -> micro:0 level:3 ordem:12 type:simulado
# Lesson -> micro:2 level:4 ordem:1 type:licao
# Lesson -> micro:2 level:4 ordem:2 type:licao
# Lesson -> micro:3 level:4 ordem:3 type:licao
# Lesson -> micro:3 level:4 ordem:4 type:licao
# Lesson -> micro:4 level:4 ordem:5 type:licao
# Lesson -> micro:4 level:4 ordem:6 type:licao
# Lesson -> micro:5 level:4 ordem:7 type:licao
# Lesson -> micro:5 level:4 ordem:8 type:licao
# Lesson -> micro:6 level:4 ordem:9 type:licao
# Lesson -> micro:6 level:4 ordem:10 type:licao
# Lesson -> micro:0 level:4 ordem:11 type:simulado
# Lesson -> micro:0 level:4 ordem:12 type:simulado
# Lesson -> micro:2 level:5 ordem:1 type:licao
# Lesson -> micro:2 level:5 ordem:2 type:licao
# Lesson -> micro:3 level:5 ordem:3 type:licao
# Lesson -> micro:3 level:5 ordem:4 type:licao
# Lesson -> micro:4 level:5 ordem:5 type:licao
# Lesson -> micro:4 level:5 ordem:6 type:licao
# Lesson -> micro:5 level:5 ordem:7 type:licao
# Lesson -> micro:5 level:5 ordem:8 type:licao
# Lesson -> micro:6 level:5 ordem:9 type:licao
# Lesson -> micro:6 level:5 ordem:10 type:licao
# Lesson -> micro:0 level:5 ordem:11 type:simulado
# Lesson -> micro:0 level:5 ordem:12 type:simulado
#  -> Preparadas 60 lessons para mesoarea 2
# Processando mesoarea 3 - citologia (microareas: 5)
# Lesson -> micro:7 level:1 ordem:1 type:licao
# Lesson -> micro:7 level:1 ordem:2 type:licao
# Lesson -> micro:8 level:1 ordem:3 type:licao
# Lesson -> micro:8 level:1 ordem:4 type:licao
# Lesson -> micro:9 level:1 ordem:5 type:licao
# Lesson -> micro:9 level:1 ordem:6 type:licao
# Lesson -> micro:10 level:1 ordem:7 type:licao
# Lesson -> micro:10 level:1 ordem:8 type:licao
# Lesson -> micro:11 level:1 ordem:9 type:licao
# Lesson -> micro:11 level:1 ordem:10 type:licao
# Lesson -> micro:0 level:1 ordem:11 type:simulado
# Lesson -> micro:0 level:1 ordem:12 type:simulado
# Lesson -> micro:7 level:2 ordem:1 type:licao
# Lesson -> micro:7 level:2 ordem:2 type:licao
# Lesson -> micro:8 level:2 ordem:3 type:licao
# Lesson -> micro:8 level:2 ordem:4 type:licao
# Lesson -> micro:9 level:2 ordem:5 type:licao
# Lesson -> micro:9 level:2 ordem:6 type:licao
# Lesson -> micro:10 level:2 ordem:7 type:licao
# Lesson -> micro:10 level:2 ordem:8 type:licao
# Lesson -> micro:11 level:2 ordem:9 type:licao
# Lesson -> micro:11 level:2 ordem:10 type:licao
# Lesson -> micro:0 level:2 ordem:11 type:simulado
# Lesson -> micro:0 level:2 ordem:12 type:simulado
# Lesson -> micro:7 level:3 ordem:1 type:licao
# Lesson -> micro:7 level:3 ordem:2 type:licao
# Lesson -> micro:8 level:3 ordem:3 type:licao
# Lesson -> micro:8 level:3 ordem:4 type:licao
# Lesson -> micro:9 level:3 ordem:5 type:licao
# Lesson -> micro:9 level:3 ordem:6 type:licao
# Lesson -> micro:10 level:3 ordem:7 type:licao
# Lesson -> micro:10 level:3 ordem:8 type:licao
# Lesson -> micro:11 level:3 ordem:9 type:licao
# Lesson -> micro:11 level:3 ordem:10 type:licao
# Lesson -> micro:0 level:3 ordem:11 type:simulado
# Lesson -> micro:0 level:3 ordem:12 type:simulado
# Lesson -> micro:7 level:4 ordem:1 type:licao
# Lesson -> micro:7 level:4 ordem:2 type:licao
# Lesson -> micro:8 level:4 ordem:3 type:licao
# Lesson -> micro:8 level:4 ordem:4 type:licao
# Lesson -> micro:9 level:4 ordem:5 type:licao
# Lesson -> micro:9 level:4 ordem:6 type:licao
# Lesson -> micro:10 level:4 ordem:7 type:licao
# Lesson -> micro:10 level:4 ordem:8 type:licao
# Lesson -> micro:11 level:4 ordem:9 type:licao
# Lesson -> micro:11 level:4 ordem:10 type:licao
# Lesson -> micro:0 level:4 ordem:11 type:simulado
# Lesson -> micro:0 level:4 ordem:12 type:simulado
# Lesson -> micro:7 level:5 ordem:1 type:licao
# Lesson -> micro:7 level:5 ordem:2 type:licao
# Lesson -> micro:8 level:5 ordem:3 type:licao
# Lesson -> micro:8 level:5 ordem:4 type:licao
# Lesson -> micro:9 level:5 ordem:5 type:licao
# Lesson -> micro:9 level:5 ordem:6 type:licao
# Lesson -> micro:10 level:5 ordem:7 type:licao
# Lesson -> micro:10 level:5 ordem:8 type:licao
# Lesson -> micro:11 level:5 ordem:9 type:licao
# Lesson -> micro:11 level:5 ordem:10 type:licao
# Lesson -> micro:0 level:5 ordem:11 type:simulado
# Lesson -> micro:0 level:5 ordem:12 type:simulado
#  -> Preparadas 60 lessons para mesoarea 3
# Processando mesoarea 4 - genetica (microareas: 5)
# Lesson -> micro:12 level:1 ordem:1 type:licao
# Lesson -> micro:12 level:1 ordem:2 type:licao
# Lesson -> micro:13 level:1 ordem:3 type:licao
# Lesson -> micro:13 level:1 ordem:4 type:licao
# Lesson -> micro:14 level:1 ordem:5 type:licao
# Lesson -> micro:14 level:1 ordem:6 type:licao
# Lesson -> micro:15 level:1 ordem:7 type:licao
# Lesson -> micro:15 level:1 ordem:8 type:licao
# Lesson -> micro:16 level:1 ordem:9 type:licao
# Lesson -> micro:16 level:1 ordem:10 type:licao
# Lesson -> micro:0 level:1 ordem:11 type:simulado
# Lesson -> micro:0 level:1 ordem:12 type:simulado
# Lesson -> micro:12 level:2 ordem:1 type:licao
# Lesson -> micro:12 level:2 ordem:2 type:licao
# Lesson -> micro:13 level:2 ordem:3 type:licao
# Lesson -> micro:13 level:2 ordem:4 type:licao
# Lesson -> micro:14 level:2 ordem:5 type:licao
# Lesson -> micro:14 level:2 ordem:6 type:licao
# Lesson -> micro:15 level:2 ordem:7 type:licao
# Lesson -> micro:15 level:2 ordem:8 type:licao
# Lesson -> micro:16 level:2 ordem:9 type:licao
# Lesson -> micro:16 level:2 ordem:10 type:licao
# Lesson -> micro:0 level:2 ordem:11 type:simulado
# Lesson -> micro:0 level:2 ordem:12 type:simulado
# Lesson -> micro:12 level:3 ordem:1 type:licao
# Lesson -> micro:12 level:3 ordem:2 type:licao
# Lesson -> micro:13 level:3 ordem:3 type:licao
# Lesson -> micro:13 level:3 ordem:4 type:licao
# Lesson -> micro:14 level:3 ordem:5 type:licao
# Lesson -> micro:14 level:3 ordem:6 type:licao
# Lesson -> micro:15 level:3 ordem:7 type:licao
# Lesson -> micro:15 level:3 ordem:8 type:licao
# Lesson -> micro:16 level:3 ordem:9 type:licao
# Lesson -> micro:16 level:3 ordem:10 type:licao
# Lesson -> micro:0 level:3 ordem:11 type:simulado
# Lesson -> micro:0 level:3 ordem:12 type:simulado
# Lesson -> micro:12 level:4 ordem:1 type:licao
# Lesson -> micro:12 level:4 ordem:2 type:licao
# Lesson -> micro:13 level:4 ordem:3 type:licao
# Lesson -> micro:13 level:4 ordem:4 type:licao
# Lesson -> micro:14 level:4 ordem:5 type:licao
# Lesson -> micro:14 level:4 ordem:6 type:licao
# Lesson -> micro:15 level:4 ordem:7 type:licao
# Lesson -> micro:15 level:4 ordem:8 type:licao
# Lesson -> micro:16 level:4 ordem:9 type:licao
# Lesson -> micro:16 level:4 ordem:10 type:licao
# Lesson -> micro:0 level:4 ordem:11 type:simulado
# Lesson -> micro:0 level:4 ordem:12 type:simulado
# Lesson -> micro:12 level:5 ordem:1 type:licao
# Lesson -> micro:12 level:5 ordem:2 type:licao
# Lesson -> micro:13 level:5 ordem:3 type:licao
# Lesson -> micro:13 level:5 ordem:4 type:licao
# Lesson -> micro:14 level:5 ordem:5 type:licao
# Lesson -> micro:14 level:5 ordem:6 type:licao
# Lesson -> micro:15 level:5 ordem:7 type:licao
# Lesson -> micro:15 level:5 ordem:8 type:licao
# Lesson -> micro:16 level:5 ordem:9 type:licao
# Lesson -> micro:16 level:5 ordem:10 type:licao
# Lesson -> micro:0 level:5 ordem:11 type:simulado
# Lesson -> micro:0 level:5 ordem:12 type:simulado
#  -> Preparadas 60 lessons para mesoarea 4
# Processando mesoarea 5 - evolucao (microareas: 4)
# Lesson -> micro:17 level:1 ordem:1 type:licao
# Lesson -> micro:17 level:1 ordem:2 type:licao
# Lesson -> micro:18 level:1 ordem:3 type:licao
# Lesson -> micro:18 level:1 ordem:4 type:licao
# Lesson -> micro:19 level:1 ordem:5 type:licao
# Lesson -> micro:19 level:1 ordem:6 type:licao
# Lesson -> micro:20 level:1 ordem:7 type:licao
# Lesson -> micro:20 level:1 ordem:8 type:licao
# Lesson -> micro:0 level:1 ordem:9 type:simulado
# Lesson -> micro:0 level:1 ordem:10 type:simulado
# Lesson -> micro:17 level:2 ordem:1 type:licao
# Lesson -> micro:17 level:2 ordem:2 type:licao
# Lesson -> micro:18 level:2 ordem:3 type:licao
# Lesson -> micro:18 level:2 ordem:4 type:licao
# Lesson -> micro:19 level:2 ordem:5 type:licao
# Lesson -> micro:19 level:2 ordem:6 type:licao
# Lesson -> micro:20 level:2 ordem:7 type:licao
# Lesson -> micro:20 level:2 ordem:8 type:licao
# Lesson -> micro:0 level:2 ordem:9 type:simulado
# Lesson -> micro:0 level:2 ordem:10 type:simulado
# Lesson -> micro:17 level:3 ordem:1 type:licao
# Lesson -> micro:17 level:3 ordem:2 type:licao
# Lesson -> micro:18 level:3 ordem:3 type:licao
# Lesson -> micro:18 level:3 ordem:4 type:licao
# Lesson -> micro:19 level:3 ordem:5 type:licao
# Lesson -> micro:19 level:3 ordem:6 type:licao
# Lesson -> micro:20 level:3 ordem:7 type:licao
# Lesson -> micro:20 level:3 ordem:8 type:licao
# Lesson -> micro:0 level:3 ordem:9 type:simulado
# Lesson -> micro:0 level:3 ordem:10 type:simulado
# Lesson -> micro:17 level:4 ordem:1 type:licao
# Lesson -> micro:17 level:4 ordem:2 type:licao
# Lesson -> micro:18 level:4 ordem:3 type:licao
# Lesson -> micro:18 level:4 ordem:4 type:licao
# Lesson -> micro:19 level:4 ordem:5 type:licao
# Lesson -> micro:19 level:4 ordem:6 type:licao
# Lesson -> micro:20 level:4 ordem:7 type:licao
# Lesson -> micro:20 level:4 ordem:8 type:licao
# Lesson -> micro:0 level:4 ordem:9 type:simulado
# Lesson -> micro:0 level:4 ordem:10 type:simulado
# Lesson -> micro:17 level:5 ordem:1 type:licao
# Lesson -> micro:17 level:5 ordem:2 type:licao
# Lesson -> micro:18 level:5 ordem:3 type:licao
# Lesson -> micro:18 level:5 ordem:4 type:licao
# Lesson -> micro:19 level:5 ordem:5 type:licao
# Lesson -> micro:19 level:5 ordem:6 type:licao
# Lesson -> micro:20 level:5 ordem:7 type:licao
# Lesson -> micro:20 level:5 ordem:8 type:licao
# Lesson -> micro:0 level:5 ordem:9 type:simulado
# Lesson -> micro:0 level:5 ordem:10 type:simulado
#  -> Preparadas 50 lessons para mesoarea 5
# Processando mesoarea 6 - microbiologia (microareas: 4)
# Lesson -> micro:21 level:1 ordem:1 type:licao
# Lesson -> micro:21 level:1 ordem:2 type:licao
# Lesson -> micro:22 level:1 ordem:3 type:licao
# Lesson -> micro:22 level:1 ordem:4 type:licao
# Lesson -> micro:23 level:1 ordem:5 type:licao
# Lesson -> micro:23 level:1 ordem:6 type:licao
# Lesson -> micro:24 level:1 ordem:7 type:licao
# Lesson -> micro:24 level:1 ordem:8 type:licao
# Lesson -> micro:0 level:1 ordem:9 type:simulado
# Lesson -> micro:0 level:1 ordem:10 type:simulado
# Lesson -> micro:21 level:2 ordem:1 type:licao
# Lesson -> micro:21 level:2 ordem:2 type:licao
# Lesson -> micro:22 level:2 ordem:3 type:licao
# Lesson -> micro:22 level:2 ordem:4 type:licao
# Lesson -> micro:23 level:2 ordem:5 type:licao
# Lesson -> micro:23 level:2 ordem:6 type:licao
# Lesson -> micro:24 level:2 ordem:7 type:licao
# Lesson -> micro:24 level:2 ordem:8 type:licao
# Lesson -> micro:0 level:2 ordem:9 type:simulado
# Lesson -> micro:0 level:2 ordem:10 type:simulado
# Lesson -> micro:21 level:3 ordem:1 type:licao
# Lesson -> micro:21 level:3 ordem:2 type:licao
# Lesson -> micro:22 level:3 ordem:3 type:licao
# Lesson -> micro:22 level:3 ordem:4 type:licao
# Lesson -> micro:23 level:3 ordem:5 type:licao
# Lesson -> micro:23 level:3 ordem:6 type:licao
# Lesson -> micro:24 level:3 ordem:7 type:licao
# Lesson -> micro:24 level:3 ordem:8 type:licao
# Lesson -> micro:0 level:3 ordem:9 type:simulado
# Lesson -> micro:0 level:3 ordem:10 type:simulado
# Lesson -> micro:21 level:4 ordem:1 type:licao
# Lesson -> micro:21 level:4 ordem:2 type:licao
# Lesson -> micro:22 level:4 ordem:3 type:licao
# Lesson -> micro:22 level:4 ordem:4 type:licao
# Lesson -> micro:23 level:4 ordem:5 type:licao
# Lesson -> micro:23 level:4 ordem:6 type:licao
# Lesson -> micro:24 level:4 ordem:7 type:licao
# Lesson -> micro:24 level:4 ordem:8 type:licao
# Lesson -> micro:0 level:4 ordem:9 type:simulado
# Lesson -> micro:0 level:4 ordem:10 type:simulado
# Lesson -> micro:21 level:5 ordem:1 type:licao
# Lesson -> micro:21 level:5 ordem:2 type:licao
# Lesson -> micro:22 level:5 ordem:3 type:licao
# Lesson -> micro:22 level:5 ordem:4 type:licao
# Lesson -> micro:23 level:5 ordem:5 type:licao
# Lesson -> micro:23 level:5 ordem:6 type:licao
# Lesson -> micro:24 level:5 ordem:7 type:licao
# Lesson -> micro:24 level:5 ordem:8 type:licao
# Lesson -> micro:0 level:5 ordem:9 type:simulado
# Lesson -> micro:0 level:5 ordem:10 type:simulado
#  -> Preparadas 50 lessons para mesoarea 6
# Processando mesoarea 7 - botanica (microareas: 6)
# Lesson -> micro:25 level:1 ordem:1 type:licao
# Lesson -> micro:25 level:1 ordem:2 type:licao
# Lesson -> micro:26 level:1 ordem:3 type:licao
# Lesson -> micro:26 level:1 ordem:4 type:licao
# Lesson -> micro:27 level:1 ordem:5 type:licao
# Lesson -> micro:27 level:1 ordem:6 type:licao
# Lesson -> micro:28 level:1 ordem:7 type:licao
# Lesson -> micro:28 level:1 ordem:8 type:licao
# Lesson -> micro:29 level:1 ordem:9 type:licao
# Lesson -> micro:29 level:1 ordem:10 type:licao
# Lesson -> micro:30 level:1 ordem:11 type:licao
# Lesson -> micro:30 level:1 ordem:12 type:licao
# Lesson -> micro:0 level:1 ordem:13 type:simulado
# Lesson -> micro:0 level:1 ordem:14 type:simulado
# Lesson -> micro:25 level:2 ordem:1 type:licao
# Lesson -> micro:25 level:2 ordem:2 type:licao
# Lesson -> micro:26 level:2 ordem:3 type:licao
# Lesson -> micro:26 level:2 ordem:4 type:licao
# Lesson -> micro:27 level:2 ordem:5 type:licao
# Lesson -> micro:27 level:2 ordem:6 type:licao
# Lesson -> micro:28 level:2 ordem:7 type:licao
# Lesson -> micro:28 level:2 ordem:8 type:licao
# Lesson -> micro:29 level:2 ordem:9 type:licao
# Lesson -> micro:29 level:2 ordem:10 type:licao
# Lesson -> micro:30 level:2 ordem:11 type:licao
# Lesson -> micro:30 level:2 ordem:12 type:licao
# Lesson -> micro:0 level:2 ordem:13 type:simulado
# Lesson -> micro:0 level:2 ordem:14 type:simulado
# Lesson -> micro:25 level:3 ordem:1 type:licao
# Lesson -> micro:25 level:3 ordem:2 type:licao
# Lesson -> micro:26 level:3 ordem:3 type:licao
# Lesson -> micro:26 level:3 ordem:4 type:licao
# Lesson -> micro:27 level:3 ordem:5 type:licao
# Lesson -> micro:27 level:3 ordem:6 type:licao
# Lesson -> micro:28 level:3 ordem:7 type:licao
# Lesson -> micro:28 level:3 ordem:8 type:licao
# Lesson -> micro:29 level:3 ordem:9 type:licao
# Lesson -> micro:29 level:3 ordem:10 type:licao
# Lesson -> micro:30 level:3 ordem:11 type:licao
# Lesson -> micro:30 level:3 ordem:12 type:licao
# Lesson -> micro:0 level:3 ordem:13 type:simulado
# Lesson -> micro:0 level:3 ordem:14 type:simulado
# Lesson -> micro:25 level:4 ordem:1 type:licao
# Lesson -> micro:25 level:4 ordem:2 type:licao
# Lesson -> micro:26 level:4 ordem:3 type:licao
# Lesson -> micro:26 level:4 ordem:4 type:licao
# Lesson -> micro:27 level:4 ordem:5 type:licao
# Lesson -> micro:27 level:4 ordem:6 type:licao
# Lesson -> micro:28 level:4 ordem:7 type:licao
# Lesson -> micro:28 level:4 ordem:8 type:licao
# Lesson -> micro:29 level:4 ordem:9 type:licao
# Lesson -> micro:29 level:4 ordem:10 type:licao
# Lesson -> micro:30 level:4 ordem:11 type:licao
# Lesson -> micro:30 level:4 ordem:12 type:licao
# Lesson -> micro:0 level:4 ordem:13 type:simulado
# Lesson -> micro:0 level:4 ordem:14 type:simulado
# Lesson -> micro:25 level:5 ordem:1 type:licao
# Lesson -> micro:25 level:5 ordem:2 type:licao
# Lesson -> micro:26 level:5 ordem:3 type:licao
# Lesson -> micro:26 level:5 ordem:4 type:licao
# Lesson -> micro:27 level:5 ordem:5 type:licao
# Lesson -> micro:27 level:5 ordem:6 type:licao
# Lesson -> micro:28 level:5 ordem:7 type:licao
# Lesson -> micro:28 level:5 ordem:8 type:licao
# Lesson -> micro:29 level:5 ordem:9 type:licao
# Lesson -> micro:29 level:5 ordem:10 type:licao
# Lesson -> micro:30 level:5 ordem:11 type:licao
# Lesson -> micro:30 level:5 ordem:12 type:licao
# Lesson -> micro:0 level:5 ordem:13 type:simulado
# Lesson -> micro:0 level:5 ordem:14 type:simulado
#  -> Preparadas 70 lessons para mesoarea 7
# Processando mesoarea 8 - embriologia_e_zoologia (microareas: 8)
# Lesson -> micro:31 level:1 ordem:1 type:licao
# Lesson -> micro:31 level:1 ordem:2 type:licao
# Lesson -> micro:32 level:1 ordem:3 type:licao
# Lesson -> micro:32 level:1 ordem:4 type:licao
# Lesson -> micro:33 level:1 ordem:5 type:licao
# Lesson -> micro:33 level:1 ordem:6 type:licao
# Lesson -> micro:34 level:1 ordem:7 type:licao
# Lesson -> micro:34 level:1 ordem:8 type:licao
# Lesson -> micro:35 level:1 ordem:9 type:licao
# Lesson -> micro:35 level:1 ordem:10 type:licao
# Lesson -> micro:36 level:1 ordem:11 type:licao
# Lesson -> micro:36 level:1 ordem:12 type:licao
# Lesson -> micro:37 level:1 ordem:13 type:licao
# Lesson -> micro:37 level:1 ordem:14 type:licao
# Lesson -> micro:38 level:1 ordem:15 type:licao
# Lesson -> micro:38 level:1 ordem:16 type:licao
# Lesson -> micro:0 level:1 ordem:17 type:simulado
# Lesson -> micro:0 level:1 ordem:18 type:simulado
# Lesson -> micro:31 level:2 ordem:1 type:licao
# Lesson -> micro:31 level:2 ordem:2 type:licao
# Lesson -> micro:32 level:2 ordem:3 type:licao
# Lesson -> micro:32 level:2 ordem:4 type:licao
# Lesson -> micro:33 level:2 ordem:5 type:licao
# Lesson -> micro:33 level:2 ordem:6 type:licao
# Lesson -> micro:34 level:2 ordem:7 type:licao
# Lesson -> micro:34 level:2 ordem:8 type:licao
# Lesson -> micro:35 level:2 ordem:9 type:licao
# Lesson -> micro:35 level:2 ordem:10 type:licao
# Lesson -> micro:36 level:2 ordem:11 type:licao
# Lesson -> micro:36 level:2 ordem:12 type:licao
# Lesson -> micro:37 level:2 ordem:13 type:licao
# Lesson -> micro:37 level:2 ordem:14 type:licao
# Lesson -> micro:38 level:2 ordem:15 type:licao
# Lesson -> micro:38 level:2 ordem:16 type:licao
# Lesson -> micro:0 level:2 ordem:17 type:simulado
# Lesson -> micro:0 level:2 ordem:18 type:simulado
# Lesson -> micro:31 level:3 ordem:1 type:licao
# Lesson -> micro:31 level:3 ordem:2 type:licao
# Lesson -> micro:32 level:3 ordem:3 type:licao
# Lesson -> micro:32 level:3 ordem:4 type:licao
# Lesson -> micro:33 level:3 ordem:5 type:licao
# Lesson -> micro:33 level:3 ordem:6 type:licao
# Lesson -> micro:34 level:3 ordem:7 type:licao
# Lesson -> micro:34 level:3 ordem:8 type:licao
# Lesson -> micro:35 level:3 ordem:9 type:licao
# Lesson -> micro:35 level:3 ordem:10 type:licao
# Lesson -> micro:36 level:3 ordem:11 type:licao
# Lesson -> micro:36 level:3 ordem:12 type:licao
# Lesson -> micro:37 level:3 ordem:13 type:licao
# Lesson -> micro:37 level:3 ordem:14 type:licao
# Lesson -> micro:38 level:3 ordem:15 type:licao
# Lesson -> micro:38 level:3 ordem:16 type:licao
# Lesson -> micro:0 level:3 ordem:17 type:simulado
# Lesson -> micro:0 level:3 ordem:18 type:simulado
# Lesson -> micro:31 level:4 ordem:1 type:licao
# Lesson -> micro:31 level:4 ordem:2 type:licao
# Lesson -> micro:32 level:4 ordem:3 type:licao
# Lesson -> micro:32 level:4 ordem:4 type:licao
# Lesson -> micro:33 level:4 ordem:5 type:licao
# Lesson -> micro:33 level:4 ordem:6 type:licao
# Lesson -> micro:34 level:4 ordem:7 type:licao
# Lesson -> micro:34 level:4 ordem:8 type:licao
# Lesson -> micro:35 level:4 ordem:9 type:licao
# Lesson -> micro:35 level:4 ordem:10 type:licao
# Lesson -> micro:36 level:4 ordem:11 type:licao
# Lesson -> micro:36 level:4 ordem:12 type:licao
# Lesson -> micro:37 level:4 ordem:13 type:licao
# Lesson -> micro:37 level:4 ordem:14 type:licao
# Lesson -> micro:38 level:4 ordem:15 type:licao
# Lesson -> micro:38 level:4 ordem:16 type:licao
# Lesson -> micro:0 level:4 ordem:17 type:simulado
# Lesson -> micro:0 level:4 ordem:18 type:simulado
# Lesson -> micro:31 level:5 ordem:1 type:licao
# Lesson -> micro:31 level:5 ordem:2 type:licao
# Lesson -> micro:32 level:5 ordem:3 type:licao
# Lesson -> micro:32 level:5 ordem:4 type:licao
# Lesson -> micro:33 level:5 ordem:5 type:licao
# Lesson -> micro:33 level:5 ordem:6 type:licao
# Lesson -> micro:34 level:5 ordem:7 type:licao
# Lesson -> micro:34 level:5 ordem:8 type:licao
# Lesson -> micro:35 level:5 ordem:9 type:licao
# Lesson -> micro:35 level:5 ordem:10 type:licao
# Lesson -> micro:36 level:5 ordem:11 type:licao
# Lesson -> micro:36 level:5 ordem:12 type:licao
# Lesson -> micro:37 level:5 ordem:13 type:licao
# Lesson -> micro:37 level:5 ordem:14 type:licao
# Lesson -> micro:38 level:5 ordem:15 type:licao
# Lesson -> micro:38 level:5 ordem:16 type:licao
# Lesson -> micro:0 level:5 ordem:17 type:simulado
# Lesson -> micro:0 level:5 ordem:18 type:simulado
#  -> Preparadas 90 lessons para mesoarea 8
# Processando mesoarea 9 - histologia (microareas: 9)
# Lesson -> micro:39 level:1 ordem:1 type:licao
# Lesson -> micro:39 level:1 ordem:2 type:licao
# Lesson -> micro:40 level:1 ordem:3 type:licao
# Lesson -> micro:40 level:1 ordem:4 type:licao
# Lesson -> micro:41 level:1 ordem:5 type:licao
# Lesson -> micro:41 level:1 ordem:6 type:licao
# Lesson -> micro:42 level:1 ordem:7 type:licao
# Lesson -> micro:42 level:1 ordem:8 type:licao
# Lesson -> micro:43 level:1 ordem:9 type:licao
# Lesson -> micro:43 level:1 ordem:10 type:licao
# Lesson -> micro:44 level:1 ordem:11 type:licao
# Lesson -> micro:44 level:1 ordem:12 type:licao
# Lesson -> micro:45 level:1 ordem:13 type:licao
# Lesson -> micro:45 level:1 ordem:14 type:licao
# Lesson -> micro:46 level:1 ordem:15 type:licao
# Lesson -> micro:46 level:1 ordem:16 type:licao
# Lesson -> micro:47 level:1 ordem:17 type:licao
# Lesson -> micro:47 level:1 ordem:18 type:licao
# Lesson -> micro:0 level:1 ordem:19 type:simulado
# Lesson -> micro:0 level:1 ordem:20 type:simulado
# Lesson -> micro:39 level:2 ordem:1 type:licao
# Lesson -> micro:39 level:2 ordem:2 type:licao
# Lesson -> micro:40 level:2 ordem:3 type:licao
# Lesson -> micro:40 level:2 ordem:4 type:licao
# Lesson -> micro:41 level:2 ordem:5 type:licao
# Lesson -> micro:41 level:2 ordem:6 type:licao
# Lesson -> micro:42 level:2 ordem:7 type:licao
# Lesson -> micro:42 level:2 ordem:8 type:licao
# Lesson -> micro:43 level:2 ordem:9 type:licao
# Lesson -> micro:43 level:2 ordem:10 type:licao
# Lesson -> micro:44 level:2 ordem:11 type:licao
# Lesson -> micro:44 level:2 ordem:12 type:licao
# Lesson -> micro:45 level:2 ordem:13 type:licao
# Lesson -> micro:45 level:2 ordem:14 type:licao
# Lesson -> micro:46 level:2 ordem:15 type:licao
# Lesson -> micro:46 level:2 ordem:16 type:licao
# Lesson -> micro:47 level:2 ordem:17 type:licao
# Lesson -> micro:47 level:2 ordem:18 type:licao
# Lesson -> micro:0 level:2 ordem:19 type:simulado
# Lesson -> micro:0 level:2 ordem:20 type:simulado
# Lesson -> micro:39 level:3 ordem:1 type:licao
# Lesson -> micro:39 level:3 ordem:2 type:licao
# Lesson -> micro:40 level:3 ordem:3 type:licao
# Lesson -> micro:40 level:3 ordem:4 type:licao
# Lesson -> micro:41 level:3 ordem:5 type:licao
# Lesson -> micro:41 level:3 ordem:6 type:licao
# Lesson -> micro:42 level:3 ordem:7 type:licao
# Lesson -> micro:42 level:3 ordem:8 type:licao
# Lesson -> micro:43 level:3 ordem:9 type:licao
# Lesson -> micro:43 level:3 ordem:10 type:licao
# Lesson -> micro:44 level:3 ordem:11 type:licao
# Lesson -> micro:44 level:3 ordem:12 type:licao
# Lesson -> micro:45 level:3 ordem:13 type:licao
# Lesson -> micro:45 level:3 ordem:14 type:licao
# Lesson -> micro:46 level:3 ordem:15 type:licao
# Lesson -> micro:46 level:3 ordem:16 type:licao
# Lesson -> micro:47 level:3 ordem:17 type:licao
# Lesson -> micro:47 level:3 ordem:18 type:licao
# Lesson -> micro:0 level:3 ordem:19 type:simulado
# Lesson -> micro:0 level:3 ordem:20 type:simulado
# Lesson -> micro:39 level:4 ordem:1 type:licao
# Lesson -> micro:39 level:4 ordem:2 type:licao
# Lesson -> micro:40 level:4 ordem:3 type:licao
# Lesson -> micro:40 level:4 ordem:4 type:licao
# Lesson -> micro:41 level:4 ordem:5 type:licao
# Lesson -> micro:41 level:4 ordem:6 type:licao
# Lesson -> micro:42 level:4 ordem:7 type:licao
# Lesson -> micro:42 level:4 ordem:8 type:licao
# Lesson -> micro:43 level:4 ordem:9 type:licao
# Lesson -> micro:43 level:4 ordem:10 type:licao
# Lesson -> micro:44 level:4 ordem:11 type:licao
# Lesson -> micro:44 level:4 ordem:12 type:licao
# Lesson -> micro:45 level:4 ordem:13 type:licao
# Lesson -> micro:45 level:4 ordem:14 type:licao
# Lesson -> micro:46 level:4 ordem:15 type:licao
# Lesson -> micro:46 level:4 ordem:16 type:licao
# Lesson -> micro:47 level:4 ordem:17 type:licao
# Lesson -> micro:47 level:4 ordem:18 type:licao
# Lesson -> micro:0 level:4 ordem:19 type:simulado
# Lesson -> micro:0 level:4 ordem:20 type:simulado
# Lesson -> micro:39 level:5 ordem:1 type:licao
# Lesson -> micro:39 level:5 ordem:2 type:licao
# Lesson -> micro:40 level:5 ordem:3 type:licao
# Lesson -> micro:40 level:5 ordem:4 type:licao
# Lesson -> micro:41 level:5 ordem:5 type:licao
# Lesson -> micro:41 level:5 ordem:6 type:licao
# Lesson -> micro:42 level:5 ordem:7 type:licao
# Lesson -> micro:42 level:5 ordem:8 type:licao
# Lesson -> micro:43 level:5 ordem:9 type:licao
# Lesson -> micro:43 level:5 ordem:10 type:licao
# Lesson -> micro:44 level:5 ordem:11 type:licao
# Lesson -> micro:44 level:5 ordem:12 type:licao
# Lesson -> micro:45 level:5 ordem:13 type:licao
# Lesson -> micro:45 level:5 ordem:14 type:licao
# Lesson -> micro:46 level:5 ordem:15 type:licao
# Lesson -> micro:46 level:5 ordem:16 type:licao
# Lesson -> micro:47 level:5 ordem:17 type:licao
# Lesson -> micro:47 level:5 ordem:18 type:licao
# Lesson -> micro:0 level:5 ordem:19 type:simulado
# Lesson -> micro:0 level:5 ordem:20 type:simulado
#  -> Preparadas 100 lessons para mesoarea 9
# Processando mesoarea 10 - fisiologia_humana (microareas: 8)
# Lesson -> micro:48 level:1 ordem:1 type:licao
# Lesson -> micro:48 level:1 ordem:2 type:licao
# Lesson -> micro:49 level:1 ordem:3 type:licao
# Lesson -> micro:49 level:1 ordem:4 type:licao
# Lesson -> micro:50 level:1 ordem:5 type:licao
# Lesson -> micro:50 level:1 ordem:6 type:licao
# Lesson -> micro:51 level:1 ordem:7 type:licao
# Lesson -> micro:51 level:1 ordem:8 type:licao
# Lesson -> micro:52 level:1 ordem:9 type:licao
# Lesson -> micro:52 level:1 ordem:10 type:licao
# Lesson -> micro:53 level:1 ordem:11 type:licao
# Lesson -> micro:53 level:1 ordem:12 type:licao
# Lesson -> micro:54 level:1 ordem:13 type:licao
# Lesson -> micro:54 level:1 ordem:14 type:licao
# Lesson -> micro:55 level:1 ordem:15 type:licao
# Lesson -> micro:55 level:1 ordem:16 type:licao
# Lesson -> micro:0 level:1 ordem:17 type:simulado
# Lesson -> micro:0 level:1 ordem:18 type:simulado
# Lesson -> micro:48 level:2 ordem:1 type:licao
# Lesson -> micro:48 level:2 ordem:2 type:licao
# Lesson -> micro:49 level:2 ordem:3 type:licao
# Lesson -> micro:49 level:2 ordem:4 type:licao
# Lesson -> micro:50 level:2 ordem:5 type:licao
# Lesson -> micro:50 level:2 ordem:6 type:licao
# Lesson -> micro:51 level:2 ordem:7 type:licao
# Lesson -> micro:51 level:2 ordem:8 type:licao
# Lesson -> micro:52 level:2 ordem:9 type:licao
# Lesson -> micro:52 level:2 ordem:10 type:licao
# Lesson -> micro:53 level:2 ordem:11 type:licao
# Lesson -> micro:53 level:2 ordem:12 type:licao
# Lesson -> micro:54 level:2 ordem:13 type:licao
# Lesson -> micro:54 level:2 ordem:14 type:licao
# Lesson -> micro:55 level:2 ordem:15 type:licao
# Lesson -> micro:55 level:2 ordem:16 type:licao
# Lesson -> micro:0 level:2 ordem:17 type:simulado
# Lesson -> micro:0 level:2 ordem:18 type:simulado
# Lesson -> micro:48 level:3 ordem:1 type:licao
# Lesson -> micro:48 level:3 ordem:2 type:licao
# Lesson -> micro:49 level:3 ordem:3 type:licao
# Lesson -> micro:49 level:3 ordem:4 type:licao
# Lesson -> micro:50 level:3 ordem:5 type:licao
# Lesson -> micro:50 level:3 ordem:6 type:licao
# Lesson -> micro:51 level:3 ordem:7 type:licao
# Lesson -> micro:51 level:3 ordem:8 type:licao
# Lesson -> micro:52 level:3 ordem:9 type:licao
# Lesson -> micro:52 level:3 ordem:10 type:licao
# Lesson -> micro:53 level:3 ordem:11 type:licao
# Lesson -> micro:53 level:3 ordem:12 type:licao
# Lesson -> micro:54 level:3 ordem:13 type:licao
# Lesson -> micro:54 level:3 ordem:14 type:licao
# Lesson -> micro:55 level:3 ordem:15 type:licao
# Lesson -> micro:55 level:3 ordem:16 type:licao
# Lesson -> micro:0 level:3 ordem:17 type:simulado
# Lesson -> micro:0 level:3 ordem:18 type:simulado
# Lesson -> micro:48 level:4 ordem:1 type:licao
# Lesson -> micro:48 level:4 ordem:2 type:licao
# Lesson -> micro:49 level:4 ordem:3 type:licao
# Lesson -> micro:49 level:4 ordem:4 type:licao
# Lesson -> micro:50 level:4 ordem:5 type:licao
# Lesson -> micro:50 level:4 ordem:6 type:licao
# Lesson -> micro:51 level:4 ordem:7 type:licao
# Lesson -> micro:51 level:4 ordem:8 type:licao
# Lesson -> micro:52 level:4 ordem:9 type:licao
# Lesson -> micro:52 level:4 ordem:10 type:licao
# Lesson -> micro:53 level:4 ordem:11 type:licao
# Lesson -> micro:53 level:4 ordem:12 type:licao
# Lesson -> micro:54 level:4 ordem:13 type:licao
# Lesson -> micro:54 level:4 ordem:14 type:licao
# Lesson -> micro:55 level:4 ordem:15 type:licao
# Lesson -> micro:55 level:4 ordem:16 type:licao
# Lesson -> micro:0 level:4 ordem:17 type:simulado
# Lesson -> micro:0 level:4 ordem:18 type:simulado
# Lesson -> micro:48 level:5 ordem:1 type:licao
# Lesson -> micro:48 level:5 ordem:2 type:licao
# Lesson -> micro:49 level:5 ordem:3 type:licao
# Lesson -> micro:49 level:5 ordem:4 type:licao
# Lesson -> micro:50 level:5 ordem:5 type:licao
# Lesson -> micro:50 level:5 ordem:6 type:licao
# Lesson -> micro:51 level:5 ordem:7 type:licao
# Lesson -> micro:51 level:5 ordem:8 type:licao
# Lesson -> micro:52 level:5 ordem:9 type:licao
# Lesson -> micro:52 level:5 ordem:10 type:licao
# Lesson -> micro:53 level:5 ordem:11 type:licao
# Lesson -> micro:53 level:5 ordem:12 type:licao
# Lesson -> micro:54 level:5 ordem:13 type:licao
# Lesson -> micro:54 level:5 ordem:14 type:licao
# Lesson -> micro:55 level:5 ordem:15 type:licao
# Lesson -> micro:55 level:5 ordem:16 type:licao
# Lesson -> micro:0 level:5 ordem:17 type:simulado
# Lesson -> micro:0 level:5 ordem:18 type:simulado
#  -> Preparadas 90 lessons para mesoarea 10
# Processando mesoarea 11 - ecologia (microareas: 5)
# Lesson -> micro:56 level:1 ordem:1 type:licao
# Lesson -> micro:56 level:1 ordem:2 type:licao
# Lesson -> micro:57 level:1 ordem:3 type:licao
# Lesson -> micro:57 level:1 ordem:4 type:licao
# Lesson -> micro:58 level:1 ordem:5 type:licao
# Lesson -> micro:58 level:1 ordem:6 type:licao
# Lesson -> micro:59 level:1 ordem:7 type:licao
# Lesson -> micro:59 level:1 ordem:8 type:licao
# Lesson -> micro:60 level:1 ordem:9 type:licao
# Lesson -> micro:60 level:1 ordem:10 type:licao
# Lesson -> micro:0 level:1 ordem:11 type:simulado
# Lesson -> micro:0 level:1 ordem:12 type:simulado
# Lesson -> micro:56 level:2 ordem:1 type:licao
# Lesson -> micro:56 level:2 ordem:2 type:licao
# Lesson -> micro:57 level:2 ordem:3 type:licao
# Lesson -> micro:57 level:2 ordem:4 type:licao
# Lesson -> micro:58 level:2 ordem:5 type:licao
# Lesson -> micro:58 level:2 ordem:6 type:licao
# Lesson -> micro:59 level:2 ordem:7 type:licao
# Lesson -> micro:59 level:2 ordem:8 type:licao
# Lesson -> micro:60 level:2 ordem:9 type:licao
# Lesson -> micro:60 level:2 ordem:10 type:licao
# Lesson -> micro:0 level:2 ordem:11 type:simulado
# Lesson -> micro:0 level:2 ordem:12 type:simulado
# Lesson -> micro:56 level:3 ordem:1 type:licao
# Lesson -> micro:56 level:3 ordem:2 type:licao
# Lesson -> micro:57 level:3 ordem:3 type:licao
# Lesson -> micro:57 level:3 ordem:4 type:licao
# Lesson -> micro:58 level:3 ordem:5 type:licao
# Lesson -> micro:58 level:3 ordem:6 type:licao
# Lesson -> micro:59 level:3 ordem:7 type:licao
# Lesson -> micro:59 level:3 ordem:8 type:licao
# Lesson -> micro:60 level:3 ordem:9 type:licao
# Lesson -> micro:60 level:3 ordem:10 type:licao
# Lesson -> micro:0 level:3 ordem:11 type:simulado
# Lesson -> micro:0 level:3 ordem:12 type:simulado
# Lesson -> micro:56 level:4 ordem:1 type:licao
# Lesson -> micro:56 level:4 ordem:2 type:licao
# Lesson -> micro:57 level:4 ordem:3 type:licao
# Lesson -> micro:57 level:4 ordem:4 type:licao
# Lesson -> micro:58 level:4 ordem:5 type:licao
# Lesson -> micro:58 level:4 ordem:6 type:licao
# Lesson -> micro:59 level:4 ordem:7 type:licao
# Lesson -> micro:59 level:4 ordem:8 type:licao
# Lesson -> micro:60 level:4 ordem:9 type:licao
# Lesson -> micro:60 level:4 ordem:10 type:licao
# Lesson -> micro:0 level:4 ordem:11 type:simulado
# Lesson -> micro:0 level:4 ordem:12 type:simulado
# Lesson -> micro:56 level:5 ordem:1 type:licao
# Lesson -> micro:56 level:5 ordem:2 type:licao
# Lesson -> micro:57 level:5 ordem:3 type:licao
# Lesson -> micro:57 level:5 ordem:4 type:licao
# Lesson -> micro:58 level:5 ordem:5 type:licao
# Lesson -> micro:58 level:5 ordem:6 type:licao
# Lesson -> micro:59 level:5 ordem:7 type:licao
# Lesson -> micro:59 level:5 ordem:8 type:licao
# Lesson -> micro:60 level:5 ordem:9 type:licao
# Lesson -> micro:60 level:5 ordem:10 type:licao
# Lesson -> micro:0 level:5 ordem:11 type:simulado
# Lesson -> micro:0 level:5 ordem:12 type:simulado
#  -> Preparadas 60 lessons para mesoarea 11
# Processando mesoarea 12 - historia_do_brasil (microareas: 4)
# Lesson -> micro:61 level:1 ordem:1 type:licao
# Lesson -> micro:61 level:1 ordem:2 type:licao
# Lesson -> micro:62 level:1 ordem:3 type:licao
# Lesson -> micro:62 level:1 ordem:4 type:licao
# Lesson -> micro:63 level:1 ordem:5 type:licao
# Lesson -> micro:63 level:1 ordem:6 type:licao
# Lesson -> micro:64 level:1 ordem:7 type:licao
# Lesson -> micro:64 level:1 ordem:8 type:licao
# Lesson -> micro:0 level:1 ordem:9 type:simulado
# Lesson -> micro:0 level:1 ordem:10 type:simulado
# Lesson -> micro:61 level:2 ordem:1 type:licao
# Lesson -> micro:61 level:2 ordem:2 type:licao
# Lesson -> micro:62 level:2 ordem:3 type:licao
# Lesson -> micro:62 level:2 ordem:4 type:licao
# Lesson -> micro:63 level:2 ordem:5 type:licao
# Lesson -> micro:63 level:2 ordem:6 type:licao
# Lesson -> micro:64 level:2 ordem:7 type:licao
# Lesson -> micro:64 level:2 ordem:8 type:licao
# Lesson -> micro:0 level:2 ordem:9 type:simulado
# Lesson -> micro:0 level:2 ordem:10 type:simulado
# Lesson -> micro:61 level:3 ordem:1 type:licao
# Lesson -> micro:61 level:3 ordem:2 type:licao
# Lesson -> micro:62 level:3 ordem:3 type:licao
# Lesson -> micro:62 level:3 ordem:4 type:licao
# Lesson -> micro:63 level:3 ordem:5 type:licao
# Lesson -> micro:63 level:3 ordem:6 type:licao
# Lesson -> micro:64 level:3 ordem:7 type:licao
# Lesson -> micro:64 level:3 ordem:8 type:licao
# Lesson -> micro:0 level:3 ordem:9 type:simulado
# Lesson -> micro:0 level:3 ordem:10 type:simulado
# Lesson -> micro:61 level:4 ordem:1 type:licao
# Lesson -> micro:61 level:4 ordem:2 type:licao
# Lesson -> micro:62 level:4 ordem:3 type:licao
# Lesson -> micro:62 level:4 ordem:4 type:licao
# Lesson -> micro:63 level:4 ordem:5 type:licao
# Lesson -> micro:63 level:4 ordem:6 type:licao
# Lesson -> micro:64 level:4 ordem:7 type:licao
# Lesson -> micro:64 level:4 ordem:8 type:licao
# Lesson -> micro:0 level:4 ordem:9 type:simulado
# Lesson -> micro:0 level:4 ordem:10 type:simulado
# Lesson -> micro:61 level:5 ordem:1 type:licao
# Lesson -> micro:61 level:5 ordem:2 type:licao
# Lesson -> micro:62 level:5 ordem:3 type:licao
# Lesson -> micro:62 level:5 ordem:4 type:licao
# Lesson -> micro:63 level:5 ordem:5 type:licao
# Lesson -> micro:63 level:5 ordem:6 type:licao
# Lesson -> micro:64 level:5 ordem:7 type:licao
# Lesson -> micro:64 level:5 ordem:8 type:licao
# Lesson -> micro:0 level:5 ordem:9 type:simulado
# Lesson -> micro:0 level:5 ordem:10 type:simulado
#  -> Preparadas 50 lessons para mesoarea 12
# Processando mesoarea 13 - historia_geral (microareas: 3)
# Lesson -> micro:65 level:1 ordem:1 type:licao
# Lesson -> micro:65 level:1 ordem:2 type:licao
# Lesson -> micro:66 level:1 ordem:3 type:licao
# Lesson -> micro:66 level:1 ordem:4 type:licao
# Lesson -> micro:67 level:1 ordem:5 type:licao
# Lesson -> micro:67 level:1 ordem:6 type:licao
# Lesson -> micro:0 level:1 ordem:7 type:simulado
# Lesson -> micro:0 level:1 ordem:8 type:simulado
# Lesson -> micro:65 level:2 ordem:1 type:licao
# Lesson -> micro:65 level:2 ordem:2 type:licao
# Lesson -> micro:66 level:2 ordem:3 type:licao
# Lesson -> micro:66 level:2 ordem:4 type:licao
# Lesson -> micro:67 level:2 ordem:5 type:licao
# Lesson -> micro:67 level:2 ordem:6 type:licao
# Lesson -> micro:0 level:2 ordem:7 type:simulado
# Lesson -> micro:0 level:2 ordem:8 type:simulado
# Lesson -> micro:65 level:3 ordem:1 type:licao
# Lesson -> micro:65 level:3 ordem:2 type:licao
# Lesson -> micro:66 level:3 ordem:3 type:licao
# Lesson -> micro:66 level:3 ordem:4 type:licao
# Lesson -> micro:67 level:3 ordem:5 type:licao
# Lesson -> micro:67 level:3 ordem:6 type:licao
# Lesson -> micro:0 level:3 ordem:7 type:simulado
# Lesson -> micro:0 level:3 ordem:8 type:simulado
# Lesson -> micro:65 level:4 ordem:1 type:licao
# Lesson -> micro:65 level:4 ordem:2 type:licao
# Lesson -> micro:66 level:4 ordem:3 type:licao
# Lesson -> micro:66 level:4 ordem:4 type:licao
# Lesson -> micro:67 level:4 ordem:5 type:licao
# Lesson -> micro:67 level:4 ordem:6 type:licao
# Lesson -> micro:0 level:4 ordem:7 type:simulado
# Lesson -> micro:0 level:4 ordem:8 type:simulado
# Lesson -> micro:65 level:5 ordem:1 type:licao
# Lesson -> micro:65 level:5 ordem:2 type:licao
# Lesson -> micro:66 level:5 ordem:3 type:licao
# Lesson -> micro:66 level:5 ordem:4 type:licao
# Lesson -> micro:67 level:5 ordem:5 type:licao
# Lesson -> micro:67 level:5 ordem:6 type:licao
# Lesson -> micro:0 level:5 ordem:7 type:simulado
# Lesson -> micro:0 level:5 ordem:8 type:simulado
#  -> Preparadas 40 lessons para mesoarea 13
# Processando mesoarea 14 - historia_da_america (microareas: 2)
# Lesson -> micro:68 level:1 ordem:1 type:licao
# Lesson -> micro:68 level:1 ordem:2 type:licao
# Lesson -> micro:69 level:1 ordem:3 type:licao
# Lesson -> micro:69 level:1 ordem:4 type:licao
# Lesson -> micro:0 level:1 ordem:5 type:simulado
# Lesson -> micro:0 level:1 ordem:6 type:simulado
# Lesson -> micro:68 level:2 ordem:1 type:licao
# Lesson -> micro:68 level:2 ordem:2 type:licao
# Lesson -> micro:69 level:2 ordem:3 type:licao
# Lesson -> micro:69 level:2 ordem:4 type:licao
# Lesson -> micro:0 level:2 ordem:5 type:simulado
# Lesson -> micro:0 level:2 ordem:6 type:simulado
# Lesson -> micro:68 level:3 ordem:1 type:licao
# Lesson -> micro:68 level:3 ordem:2 type:licao
# Lesson -> micro:69 level:3 ordem:3 type:licao
# Lesson -> micro:69 level:3 ordem:4 type:licao
# Lesson -> micro:0 level:3 ordem:5 type:simulado
# Lesson -> micro:0 level:3 ordem:6 type:simulado
# Lesson -> micro:68 level:4 ordem:1 type:licao
# Lesson -> micro:68 level:4 ordem:2 type:licao
# Lesson -> micro:69 level:4 ordem:3 type:licao
# Lesson -> micro:69 level:4 ordem:4 type:licao
# Lesson -> micro:0 level:4 ordem:5 type:simulado
# Lesson -> micro:0 level:4 ordem:6 type:simulado
# Lesson -> micro:68 level:5 ordem:1 type:licao
# Lesson -> micro:68 level:5 ordem:2 type:licao
# Lesson -> micro:69 level:5 ordem:3 type:licao
# Lesson -> micro:69 level:5 ordem:4 type:licao
# Lesson -> micro:0 level:5 ordem:5 type:simulado
# Lesson -> micro:0 level:5 ordem:6 type:simulado
#  -> Preparadas 30 lessons para mesoarea 14
# Processando mesoarea 15 - cidadania_e_direitos (microareas: 1)
# Lesson -> micro:70 level:1 ordem:1 type:licao
# Lesson -> micro:70 level:1 ordem:2 type:licao
# Lesson -> micro:0 level:1 ordem:3 type:simulado
# Lesson -> micro:0 level:1 ordem:4 type:simulado
# Lesson -> micro:70 level:2 ordem:1 type:licao
# Lesson -> micro:70 level:2 ordem:2 type:licao
# Lesson -> micro:0 level:2 ordem:3 type:simulado
# Lesson -> micro:0 level:2 ordem:4 type:simulado
# Lesson -> micro:70 level:3 ordem:1 type:licao
# Lesson -> micro:70 level:3 ordem:2 type:licao
# Lesson -> micro:0 level:3 ordem:3 type:simulado
# Lesson -> micro:0 level:3 ordem:4 type:simulado
# Lesson -> micro:70 level:4 ordem:1 type:licao
# Lesson -> micro:70 level:4 ordem:2 type:licao
# Lesson -> micro:0 level:4 ordem:3 type:simulado
# Lesson -> micro:0 level:4 ordem:4 type:simulado
# Lesson -> micro:70 level:5 ordem:1 type:licao
# Lesson -> micro:70 level:5 ordem:2 type:licao
# Lesson -> micro:0 level:5 ordem:3 type:simulado
# Lesson -> micro:0 level:5 ordem:4 type:simulado
#  -> Preparadas 20 lessons para mesoarea 15
# Processando mesoarea 16 - geografia_fisica (microareas: 3)
# Lesson -> micro:71 level:1 ordem:1 type:licao
# Lesson -> micro:71 level:1 ordem:2 type:licao
# Lesson -> micro:72 level:1 ordem:3 type:licao
# Lesson -> micro:72 level:1 ordem:4 type:licao
# Lesson -> micro:73 level:1 ordem:5 type:licao
# Lesson -> micro:73 level:1 ordem:6 type:licao
# Lesson -> micro:0 level:1 ordem:7 type:simulado
# Lesson -> micro:0 level:1 ordem:8 type:simulado
# Lesson -> micro:71 level:2 ordem:1 type:licao
# Lesson -> micro:71 level:2 ordem:2 type:licao
# Lesson -> micro:72 level:2 ordem:3 type:licao
# Lesson -> micro:72 level:2 ordem:4 type:licao
# Lesson -> micro:73 level:2 ordem:5 type:licao
# Lesson -> micro:73 level:2 ordem:6 type:licao
# Lesson -> micro:0 level:2 ordem:7 type:simulado
# Lesson -> micro:0 level:2 ordem:8 type:simulado
# Lesson -> micro:71 level:3 ordem:1 type:licao
# Lesson -> micro:71 level:3 ordem:2 type:licao
# Lesson -> micro:72 level:3 ordem:3 type:licao
# Lesson -> micro:72 level:3 ordem:4 type:licao
# Lesson -> micro:73 level:3 ordem:5 type:licao
# Lesson -> micro:73 level:3 ordem:6 type:licao
# Lesson -> micro:0 level:3 ordem:7 type:simulado
# Lesson -> micro:0 level:3 ordem:8 type:simulado
# Lesson -> micro:71 level:4 ordem:1 type:licao
# Lesson -> micro:71 level:4 ordem:2 type:licao
# Lesson -> micro:72 level:4 ordem:3 type:licao
# Lesson -> micro:72 level:4 ordem:4 type:licao
# Lesson -> micro:73 level:4 ordem:5 type:licao
# Lesson -> micro:73 level:4 ordem:6 type:licao
# Lesson -> micro:0 level:4 ordem:7 type:simulado
# Lesson -> micro:0 level:4 ordem:8 type:simulado
# Lesson -> micro:71 level:5 ordem:1 type:licao
# Lesson -> micro:71 level:5 ordem:2 type:licao
# Lesson -> micro:72 level:5 ordem:3 type:licao
# Lesson -> micro:72 level:5 ordem:4 type:licao
# Lesson -> micro:73 level:5 ordem:5 type:licao
# Lesson -> micro:73 level:5 ordem:6 type:licao
# Lesson -> micro:0 level:5 ordem:7 type:simulado
# Lesson -> micro:0 level:5 ordem:8 type:simulado
#  -> Preparadas 40 lessons para mesoarea 16
# Processando mesoarea 17 - geografia_humana (microareas: 2)
# Lesson -> micro:74 level:1 ordem:1 type:licao
# Lesson -> micro:74 level:1 ordem:2 type:licao
# Lesson -> micro:75 level:1 ordem:3 type:licao
# Lesson -> micro:75 level:1 ordem:4 type:licao
# Lesson -> micro:0 level:1 ordem:5 type:simulado
# Lesson -> micro:0 level:1 ordem:6 type:simulado
# Lesson -> micro:74 level:2 ordem:1 type:licao
# Lesson -> micro:74 level:2 ordem:2 type:licao
# Lesson -> micro:75 level:2 ordem:3 type:licao
# Lesson -> micro:75 level:2 ordem:4 type:licao
# Lesson -> micro:0 level:2 ordem:5 type:simulado
# Lesson -> micro:0 level:2 ordem:6 type:simulado
# Lesson -> micro:74 level:3 ordem:1 type:licao
# Lesson -> micro:74 level:3 ordem:2 type:licao
# Lesson -> micro:75 level:3 ordem:3 type:licao
# Lesson -> micro:75 level:3 ordem:4 type:licao
# Lesson -> micro:0 level:3 ordem:5 type:simulado
# Lesson -> micro:0 level:3 ordem:6 type:simulado
# Lesson -> micro:74 level:4 ordem:1 type:licao
# Lesson -> micro:74 level:4 ordem:2 type:licao
# Lesson -> micro:75 level:4 ordem:3 type:licao
# Lesson -> micro:75 level:4 ordem:4 type:licao
# Lesson -> micro:0 level:4 ordem:5 type:simulado
# Lesson -> micro:0 level:4 ordem:6 type:simulado
# Lesson -> micro:74 level:5 ordem:1 type:licao
# Lesson -> micro:74 level:5 ordem:2 type:licao
# Lesson -> micro:75 level:5 ordem:3 type:licao
# Lesson -> micro:75 level:5 ordem:4 type:licao
# Lesson -> micro:0 level:5 ordem:5 type:simulado
# Lesson -> micro:0 level:5 ordem:6 type:simulado
#  -> Preparadas 30 lessons para mesoarea 17
# Processando mesoarea 18 - geografia_politica (microareas: 1)
# Lesson -> micro:76 level:1 ordem:1 type:licao
# Lesson -> micro:76 level:1 ordem:2 type:licao
# Lesson -> micro:0 level:1 ordem:3 type:simulado
# Lesson -> micro:0 level:1 ordem:4 type:simulado
# Lesson -> micro:76 level:2 ordem:1 type:licao
# Lesson -> micro:76 level:2 ordem:2 type:licao
# Lesson -> micro:0 level:2 ordem:3 type:simulado
# Lesson -> micro:0 level:2 ordem:4 type:simulado
# Lesson -> micro:76 level:3 ordem:1 type:licao
# Lesson -> micro:76 level:3 ordem:2 type:licao
# Lesson -> micro:0 level:3 ordem:3 type:simulado
# Lesson -> micro:0 level:3 ordem:4 type:simulado
# Lesson -> micro:76 level:4 ordem:1 type:licao
# Lesson -> micro:76 level:4 ordem:2 type:licao
# Lesson -> micro:0 level:4 ordem:3 type:simulado
# Lesson -> micro:0 level:4 ordem:4 type:simulado
# Lesson -> micro:76 level:5 ordem:1 type:licao
# Lesson -> micro:76 level:5 ordem:2 type:licao
# Lesson -> micro:0 level:5 ordem:3 type:simulado
# Lesson -> micro:0 level:5 ordem:4 type:simulado
#  -> Preparadas 20 lessons para mesoarea 18
# Processando mesoarea 19 - geografia_do_brasil (microareas: 2)
# Lesson -> micro:77 level:1 ordem:1 type:licao
# Lesson -> micro:77 level:1 ordem:2 type:licao
# Lesson -> micro:78 level:1 ordem:3 type:licao
# Lesson -> micro:78 level:1 ordem:4 type:licao
# Lesson -> micro:0 level:1 ordem:5 type:simulado
# Lesson -> micro:0 level:1 ordem:6 type:simulado
# Lesson -> micro:77 level:2 ordem:1 type:licao
# Lesson -> micro:77 level:2 ordem:2 type:licao
# Lesson -> micro:78 level:2 ordem:3 type:licao
# Lesson -> micro:78 level:2 ordem:4 type:licao
# Lesson -> micro:0 level:2 ordem:5 type:simulado
# Lesson -> micro:0 level:2 ordem:6 type:simulado
# Lesson -> micro:77 level:3 ordem:1 type:licao
# Lesson -> micro:77 level:3 ordem:2 type:licao
# Lesson -> micro:78 level:3 ordem:3 type:licao
# Lesson -> micro:78 level:3 ordem:4 type:licao
# Lesson -> micro:0 level:3 ordem:5 type:simulado
# Lesson -> micro:0 level:3 ordem:6 type:simulado
# Lesson -> micro:77 level:4 ordem:1 type:licao
# Lesson -> micro:77 level:4 ordem:2 type:licao
# Lesson -> micro:78 level:4 ordem:3 type:licao
# Lesson -> micro:78 level:4 ordem:4 type:licao
# Lesson -> micro:0 level:4 ordem:5 type:simulado
# Lesson -> micro:0 level:4 ordem:6 type:simulado
# Lesson -> micro:77 level:5 ordem:1 type:licao
# Lesson -> micro:77 level:5 ordem:2 type:licao
# Lesson -> micro:78 level:5 ordem:3 type:licao
# Lesson -> micro:78 level:5 ordem:4 type:licao
# Lesson -> micro:0 level:5 ordem:5 type:simulado
# Lesson -> micro:0 level:5 ordem:6 type:simulado
#  -> Preparadas 30 lessons para mesoarea 19
# Processando mesoarea 21 - cartografia_e_tecnologia (microareas: 1)
# Lesson -> micro:79 level:1 ordem:1 type:licao
# Lesson -> micro:79 level:1 ordem:2 type:licao
# Lesson -> micro:0 level:1 ordem:3 type:simulado
# Lesson -> micro:0 level:1 ordem:4 type:simulado
# Lesson -> micro:79 level:2 ordem:1 type:licao
# Lesson -> micro:79 level:2 ordem:2 type:licao
# Lesson -> micro:0 level:2 ordem:3 type:simulado
# Lesson -> micro:0 level:2 ordem:4 type:simulado
# Lesson -> micro:79 level:3 ordem:1 type:licao
# Lesson -> micro:79 level:3 ordem:2 type:licao
# Lesson -> micro:0 level:3 ordem:3 type:simulado
# Lesson -> micro:0 level:3 ordem:4 type:simulado
# Lesson -> micro:79 level:4 ordem:1 type:licao
# Lesson -> micro:79 level:4 ordem:2 type:licao
# Lesson -> micro:0 level:4 ordem:3 type:simulado
# Lesson -> micro:0 level:4 ordem:4 type:simulado
# Lesson -> micro:79 level:5 ordem:1 type:licao
# Lesson -> micro:79 level:5 ordem:2 type:licao
# Lesson -> micro:0 level:5 ordem:3 type:simulado
# Lesson -> micro:0 level:5 ordem:4 type:simulado
#  -> Preparadas 20 lessons para mesoarea 21
# Processando mesoarea 20 - meio_ambiente_e_sustentab (microareas: 0)
# Mesoarea 20 não tem microareas. Pulando.
#  -> Preparadas 0 lessons para mesoarea 20
# Total de lessons a inserir: 970
# Inseridas 970 rows na tabela lesson
